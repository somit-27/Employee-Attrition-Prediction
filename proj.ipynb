# %% [markdown]
# IMPORTING THE NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as matplot
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# OBTAINING THE DATA

# %%
df=pd.read_csv("HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# CHECKING MISSING VALUES

# %%
#Check to see if there are any missing values in our data set
df.isnull().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# Department               False
# salary                   False
# dtype: bool

# %% [markdown]
# CHECKING THE DIMENSIONS OF THE DATASET

# %%
# The dataset contains 10 columns and 14999 observations
df.shape
# Out:
# (14999, 10)

# %% [markdown]
# Z SCORE STANDARDISATION

# %%
df_z_scaled = df.copy()
  
# apply normalization technique to Column 1
column = 'average_montly_hours'
df_z_scaled[column] = (df_z_scaled[column] - df_z_scaled[column].mean()) / df_z_scaled[column].std()    
  
# view normalized data  
display(df_z_scaled)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                 -0.882010                   3              0     1
# 1                  1.220382                   6              0     1
# ...

# %% [markdown]
# MIN MAX NORMALIZATION

# %%
df_min_max_scaled = df
  
# apply normalization technique
column = 'average_montly_hours'
df_min_max_scaled[column] = (df_min_max_scaled[column] - df_min_max_scaled[column].min()) / (df_min_max_scaled[column].max() - df_min_max_scaled[column].min())    
  
# view normalized data
display(df_min_max_scaled)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                  0.285047                   3              0     1
# 1                  0.775701                   6              0     1
# ...

# %% [markdown]
# DECIMAL SCALING

# %%
df_decimal_scaled=df
column = 'average_montly_hours'
df_decimal_scaled[column] = df_decimal_scaled[column]/10**3
df_decimal_scaled
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                     0.157                   3              0     1
# 1                     0.262                   6              0     1
# ...

# %%
df1=df

# %%
df1.left
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
df1.left.value_counts() 
# 0 means stayed 1 means left
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
turnover_rate = df1.left.value_counts() / len(df1)
turnover_rate
#76% stayed ,  24% left
# Out:
# 0    0.761917
# 1    0.238083
# Name: left, dtype: float64

# %%
turnover_Summary = df1.groupby('left')
turnover_Summary.mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %% [markdown]
# CORRELATION

# %%
#Correlation Matrix
sns.heatmap(df1.corr(), 
            cmap = "YlGnBu",
            annot = True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pylab as plt
plt.scatter([1, 2, 4, 5], [5, 6, 7, 8])
